# %% [markdown]
# <a href="https://colab.research.google.com/github/N1ck1103/Sport-cars-vs-Muscle-cas/blob/main/Nicholas_Smith_Lab_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# brings in matplotlib.pyplot and renames it to plt.

# %%
from skimage.io import imread

#From skimage.io means that inside there and then import imread means bring imread from the skimage.io site

# %%
from skimage.transform import resize

# same thing from last cell except you are importing resize this time.

# %%
url = 'https://www.motorious.com/content/images/size/w1000/2020/07/1976-pontiac-trans-am-6.jpg'
# url of the website for the image.

# %%
im = imread(url)

# reassigning im to imread(url)

# %%
im.shape
#size of the image
# Out:
# (563, 1000, 3)

# %%
plt.figure(figsize=(20,10))
plt.imshow(im);
plt.axis('off')

#first line means the size of the image. second line is the plotting of the image along with the size and the third and final line means that it wants an off axis plotting of the image.
# Out:
# (-0.5, 999.5, 562.5, -0.5)

# %%
im.reshape(-1)
#refers to an unknown dimension that the reshape() function calculates for you.
# Out:
# array([ 72,  85,  67, ..., 198, 194, 191], dtype=uint8)

# %%
im 
#produces multiple random arrays
# Out:
# array([[[ 72,  85,  67],
#         [ 77,  90,  72],
#         [ 83,  96,  78],
#         ...,
#         [140, 134, 100],
#         [140, 134, 100],
#         [118, 112,  78]],
#
#        [[ 88, 101,  83],
#         [ 93, 106,  88],
#         [ 98, 111,  91],
#         ...,
#         [131, 125,  91],
#         [144, 138, 104],
#         [131, 125,  91]],
#
#        [[103, 115,  93],
#         [106, 118,  96],
#         [110, 122, 100],
#         ...,
#         [169, 163, 129],
#         [152, 146, 112],
#         [185, 179, 145]],
#
#        ...,
#
#        [[211, 207, 204],
#         [215, 211, 208],
#         [166, 162, 159],
#         ...,
#         [167, 163, 160],
#         [168, 164, 161],
#         [195, 191, 188]],
#
#        [[207, 203, 200],
#         [213, 209, 206],
#         [184, 180, 177],
#         ...,
#         [242, 238, 235],
#         [215, 211, 208],
#         [166, 162, 159]],
#
#        [[200, 196, 193],
#         [207, 203, 200],
#         [204, 200, 197],
# ...

# %%
im_flattened = im.reshape
# reassigns im_flattened to im.reshape

# %%
plt.imshow(im) ;
#

# %%
plt.imshow(im[:,:,0])
# the third 0 means that the color of the image will be a greenish

# %%
plt.imshow(im[10:50,:,0])

# 10 pixels down then show 40 pixels of the image

# %%
plt.imshow(im[:,100:200,:])

# 100 pixels to the right and then you have 100 pixels left to show around

# %%
plt.imshow(im[:,120:240,:])
# means 120 pixels to the right and then subtract that from the 240 pixels wanting to be shown and your left with 240 pixels

# %%
plt.imshow(im[:,240:300,:])
# 240 pixels to the right and only show 60 pixels wide of it
